# %% [raw]
# ---
# description: This is a library for doing 2D ray tracing.
# output-file: core.html
# title: PlanoLux
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This is the basic class for 2D points.

# %%
#| echo: false
#| output: asis
show_doc(Point)
# Out:
# ---
#
# [source](https://github.com/iohazard/planolux/blob/main/planolux/core.py#L11){target="_blank" style="float:right; font-size:smaller"}
#
# ### Point
#
# >      Point (xi, yi)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# This is the class for a ray, or vector with origin point.

# %%
#| echo: false
#| output: asis
show_doc(Ray)
# Out:
# ---
#
# [source](https://github.com/iohazard/planolux/blob/main/planolux/core.py#L53){target="_blank" style="float:right; font-size:smaller"}
#
# ### Ray
#
# >      Ray (ai, bi, ii=1.0)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# This is a surface to reflect, refract, absorb, scatter, image at.
#
# This needs to be ref/ref, ref only, absorb only, scatter

# %%
#| echo: false
#| output: asis
show_doc(Surface)
# Out:
# ---
#
# [source](https://github.com/iohazard/planolux/blob/main/planolux/core.py#L66){target="_blank" style="float:right; font-size:smaller"}
#
# ### Surface
#
# >      Surface (ai, bi, n1=1.0, n2=1.5)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# Intersection and ray casting.

# %%
#| echo: false
#| output: asis
show_doc(plot_scene)
# Out:
# ---
#
# [source](https://github.com/iohazard/planolux/blob/main/planolux/core.py#L121){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_scene
#
# >      plot_scene (rays, surfs, sp, raycol='red')

# %%
#| echo: false
#| output: asis
show_doc(gen_rays)
# Out:
# ---
#
# [source](https://github.com/iohazard/planolux/blob/main/planolux/core.py#L111){target="_blank" style="float:right; font-size:smaller"}
#
# ### gen_rays
#
# >      gen_rays (sp=<__main__.Point object at 0x7fa6e22f2a70>, ao=-180, ae=180,
# >                na=60, endpoint=True)

# %%
#| echo: false
#| output: asis
show_doc(cast)
# Out:
# ---
#
# [source](https://github.com/iohazard/planolux/blob/main/planolux/core.py#L96){target="_blank" style="float:right; font-size:smaller"}
#
# ### cast
#
# >      cast (r, surf)

# %%
#| echo: false
#| output: asis
show_doc(intersect)
# Out:
# ---
#
# [source](https://github.com/iohazard/planolux/blob/main/planolux/core.py#L83){target="_blank" style="float:right; font-size:smaller"}
#
# ### intersect
#
# >      intersect (R, S)

# %% [markdown]
# Now show this works.

# %% [markdown]
# ## Vector Reflection
# For an incoming ray $\vec{s}$ and a surface normal $\vec{n}$ the reflected ray $\vec{v}_{reflect}$
#
# $$ \vec{v}_{reflect} = \vec{s} - 2 (\vec{s} \cdot \vec{n}) \vec{n}$$

# %%
#| echo: false
#| output: asis
show_doc(reflect)
# Out:
# ---
#
# [source](https://github.com/iohazard/planolux/blob/main/planolux/core.py#L144){target="_blank" style="float:right; font-size:smaller"}
#
# ### reflect
#
# >      reflect (R, S, P)

# %% [markdown]
# This checked reflections at various angles.

# %% [markdown]
# ## Vector refraction Snell's Law
#
# For an incoming ray $\vec{s}$ and a surface normal $\vec{n}$ the refracted ray $\vec{v}_{refract}$
#
# $$\vec{v}_{refract} = r \vec{s} + \left( r c - \sqrt{1-r^2 (1-c^2)} \vec{n} \right)$$
#
# where $r = \frac{n_1}{n_2}$ and $c = -\vec{n} \cdot \vec{s}$.

# %%
#| echo: false
#| output: asis
show_doc(refract)
# Out:
# ---
#
# [source](https://github.com/iohazard/planolux/blob/main/planolux/core.py#L156){target="_blank" style="float:right; font-size:smaller"}
#
# ### refract
#
# >      refract (R, S, P)

# %%
#| echo: false
#| output: asis
show_doc(lens)
# Out:
# ---
#
# [source](https://github.com/iohazard/planolux/blob/main/planolux/core.py#L178){target="_blank" style="float:right; font-size:smaller"}
#
# ### lens
#
# >      lens (R1, R2, T, H, XL, N=16)

# %% [markdown]
# Ray caster should start at sp, array of cast rays added to list with initial intensity.
#
# Every ray is intersected with every surface. Closest surface (in direction of ray) is chosen as first intersect. Intersect position noted as new source point, reflected and refracted rays generated. Intensity of each decreased.
#
# Rays removed with no intersections left or intensity too low.
#
# ## Fresnel Equations

# %%
#| echo: false
#| output: asis
show_doc(reflectance)
# Out:
# ---
#
# [source](https://github.com/iohazard/planolux/blob/main/planolux/core.py#L199){target="_blank" style="float:right; font-size:smaller"}
#
# ### reflectance
#
# >      reflectance (r, sc)

# %% [markdown]
# Now lets see all the reflect and refract work.

# %%
surf = []
surf.append(Surface(Point(4,2), Point(2,2), n2=1.5))
surf.append(Surface(Point(3,0), Point(4,2), n2=1.5))
surf.append(Surface(Point(2,2), Point(3,0), n2=1.5))


# Source Point
sp    = Point(0.0,1.0)

# Initial Rays
rays_out = gen_rays(sp, -10, 10, 5, endpoint=False)

# %%
#| echo: false
#| output: asis
show_doc(raytrace)
# Out:
# ---
#
# [source](https://github.com/iohazard/planolux/blob/main/planolux/core.py#L218){target="_blank" style="float:right; font-size:smaller"}
#
# ### raytrace
#
# >      raytrace (rays_out, surf, reflect_rays=True, refract_rays=True, DEPTH=10,
# >                RT=0.001, verbose=False)

# %%
rays_all = raytrace(rays_out, surf)
plot_scene(rays_all, surf, sp, raycol='red')
